# %% [markdown]
# <a href="https://colab.research.google.com/github/Anupriya606/AI-furniture-assistant/blob/main/image_caption_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow numpy matplotlib tqdm pillow

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
import tensorflow as tf

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = "/content/drive/MyDrive/ImageCaptionProject"

os.makedirs(base_path, exist_ok=True)
os.makedirs(base_path + "/data", exist_ok=True)
os.makedirs(base_path + "/models", exist_ok=True)
os.makedirs(base_path + "/results", exist_ok=True)

print("Folders created!")
# Out:
# Folders created!

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/ImageCaptionProject/data/Images.zip"
extract_path = "/content/drive/MyDrive/ImageCaptionProject/data/Images"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Images extracted successfully!")
# Out:
# Images extracted successfully!

# %%
base_path = "/content/drive/MyDrive/ImageCaptionProject/data"

captions_path = base_path + "/captions.txt"
images_path = base_path + "/Images"

print(captions_path)
print(images_path)
# Out:
# /content/drive/MyDrive/ImageCaptionProject/data/captions.txt
# /content/drive/MyDrive/ImageCaptionProject/data/Images

# %%
def load_captions(path):
    captions = {}

    with open(path, 'r', encoding='utf-8') as file:
        for line in file:
            tokens = line.strip().split(',')

            if len(tokens) < 2:
                continue

            image_id = tokens[0].split('.')[0]
            caption = tokens[1]

            if image_id not in captions:
                captions[image_id] = []

            captions[image_id].append(caption)

    return captions


captions = load_captions(captions_path)
print("Total images:", len(captions))
# Out:
# Total images: 8092

# %%
import string
import re

def clean_captions(captions):
    table = str.maketrans('', '', string.punctuation)

    for key, desc_list in captions.items():
        for i in range(len(desc_list)):
            desc = desc_list[i]

            desc = desc.lower()
            desc = desc.translate(table)
            desc = re.sub(r'\s+', ' ', desc).strip()

            desc_list[i] = 'startseq ' + desc + ' endseq'

    return captions


captions = clean_captions(captions)

# check sample
for key in list(captions.keys())[:1]:
    print(captions[key])
# Out:
# ['startseq caption endseq']
